# %%
from google.colab import drive
import os

gdrive_path='/content/gdrive/MyDrive/Detection'

# Mounting your google drive under 'MyDrive'
drive.mount('/content/gdrive', force_remount=True)

# Access the files in this notebook we have to navigate to the correct folder
os.chdir(gdrive_path)
# Out:
# Mounted at /content/gdrive

# %%
# !pip install ultralytics
from ultralytics import YOLO

# %%
# Load the pre-trained YOLOv8 model

model = YOLO('yolov8n.pt')

# Start training
model.train(data='data.yaml', imgsz=640, batch=16, epochs=100, device=0)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import cv2
from matplotlib import pyplot as plt

# Load the trained model
model = YOLO(gdrive_path + "/runs/detect/train/weights/best.pt")

# Folder containing test images
image_folder = "test_images/"
output_folder = "predictions/"  # Folder to save output images
os.makedirs(output_folder, exist_ok=True)  # Create folder if it doesn't exist

# Get all image paths in the folder
image_paths = [os.path.join(image_folder, img) for img in os.listdir(image_folder) if img.endswith(('.png', '.jpg', '.jpeg'))]

# Process each image
for image_path in image_paths:
    # Predict on the image
    results = model.predict(source=image_path, imgsz=640, conf=0.5)

    # Visualize predictions
    results_image = results[0].plot()  # Render predictions on the image

    # Save the resulting image
    output_image_path = os.path.join(output_folder, os.path.basename(image_path))
    cv2.imwrite(output_image_path, results_image)  # Save to output folder

    # Display the image (optional, remove if processing many images to save time)
    plt.figure(figsize=(8, 8))
    plt.imshow(cv2.cvtColor(results_image, cv2.COLOR_BGR2RGB))
    plt.title(os.path.basename(image_path))
    plt.axis('off')
    plt.show()
# Out:
# image 1/1 /content/gdrive/MyDrive/Detection/test_images/number-5.png: 320x640 1 5, 80.6ms
# Speed: 2.9ms preprocess, 80.6ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
# image 1/1 /content/gdrive/MyDrive/Detection/test_images/number-1.png: 640x640 1 1, 10.9ms
# Speed: 4.3ms preprocess, 10.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
